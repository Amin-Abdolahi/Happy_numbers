# %%
'''
    this program checks if a number is a happy number
A happy number is a number which eventually reaches 1 when replaced by the sum of the square of each digit.
If it enters a cycle which does not include 1, it is not a happy number.
The process of repeatedly replacing a number by the sum of the squares of its digits is called "digit squaring".
The first few happy numbers are: 1, 7, 10, 13, 19, 23, 28, 31, 32, 44, 49, 68, 70, 79, 82, 86, 91, 94, 97, 100
'''
# step 1: get a number from user
user_number = input("Enter your number: ")
# step 2: Check if a number is a happy number
def is_happy_number(n):
    while n != 1 and n != 4:
        n = sum(int(digit) ** 2 for digit in str(n))
    return n == 1

# step 3: Print the result
if is_happy_number(int(user_number)):
    print(user_number, "is a happy number.")
else:
    print(user_number, "is not a happy number.")
    
print("The process of digit squaring for", user_number, "is as follows:")
n = int(user_number)
while n != 1 and n != 4:
    n = sum(int(digit) ** 2 for digit in str(n))
    print(n)
# Out:
# 9985 is not a happy number.
# The process of digit squaring for 9985 is as follows:
# 251
# 30
# 9
# 81
# 65
# 61
# 37
# 58
# 89
# 145
# 42
# 20
# 4

# %%
for i in range(1, 10000):
    if is_happy_number(i):
        print(i, "is a happy number.")
# Out:
# 1 is a happy number.
# 7 is a happy number.
# 10 is a happy number.
# 13 is a happy number.
# 19 is a happy number.
# 23 is a happy number.
# 28 is a happy number.
# 31 is a happy number.
# 32 is a happy number.
# 44 is a happy number.
# 49 is a happy number.
# 68 is a happy number.
# 70 is a happy number.
# 79 is a happy number.
# 82 is a happy number.
# 86 is a happy number.
# 91 is a happy number.
# 94 is a happy number.
# 97 is a happy number.
# 100 is a happy number.
# 103 is a happy number.
# 109 is a happy number.
# 129 is a happy number.
# 130 is a happy number.
# 133 is a happy number.
# 139 is a happy number.
# 167 is a happy number.
# 176 is a happy number.
# 188 is a happy number.
# 190 is a happy number.
# 192 is a happy number.
# 193 is a happy number.
# 203 is a happy number.
# 208 is a happy number.
# 219 is a happy number.
# 226 is a happy number.
# 230 is a happy number.
# 236 is a happy number.
# 239 is a happy number.
# 262 is a happy number.
# 263 is a happy number.
# 280 is a happy number.
# 291 is a happy number.
# 293 is a happy number.
# 301 is a happy number.
# 302 is a happy number.
# 310 is a happy number.
# 313 is a happy number.
# 319 is a happy number.
# 320 is a happy number.
# 326 is a happy number.
# 329 is a happy number.
# 331 is a happy number.
# 338 is a happy number.
# 356 is a happy number.
# 362 is a happy number.
# 365 is a happy number.
# 367 is a happy number.
# 368 is a happy number.
# 376 is a happy number.
# 379 is a happy number.
# 383 is a happy number.
# 386 is a happy number.
# 391 is a happy number.
# 392 is a happy number.
# 397 is a happy number.
# 404 is a happy number.
# 409 is a happy number.
# 440 is a happy number.
# 446 is a happy number.
# 464 is a happy number.
# 469 is a happy number.
# 478 is a happy number.
# 487 is a happy number.
# 490 is a happy number.
# 496 is a happy number.
# 536 is a happy number.
# 556 is a happy number.
# 563 is a happy number.
# 565 is a happy number.
# 566 is a happy number.
# 608 is a happy number.
# 617 is a happy number.
# 622 is a happy number.
# 623 is a happy number.
# 632 is a happy number.
# 635 is a happy number.
# 637 is a happy number.
# 638 is a happy number.
# 644 is a happy number.
# 649 is a happy number.
# 653 is a happy number.
# 655 is a happy number.
# 656 is a happy number.
# 665 is a happy number.
# 671 is a happy number.
# 673 is a happy number.
# 680 is a happy number.
# 683 is a happy number.
# 694 is a happy number.
# 700 is a happy number.
# 709 is a happy number.
# 716 is a happy number.
# 736 is a happy number.
# 739 is a happy number.
# 748 is a happy number.
# 761 is a happy number.
# 763 is a happy number.
# 784 is a happy number.
# 790 is a happy number.
# 793 is a happy number.
# 802 is a happy number.
# 806 is a happy number.
# 818 is a happy number.
# 820 is a happy number.
# 833 is a happy number.
# 836 is a happy number.
# 847 is a happy number.
# 860 is a happy number.
# 863 is a happy number.
# 874 is a happy number.
# 881 is a happy number.
# 888 is a happy number.
# 899 is a happy number.
# 901 is a happy number.
# 904 is a happy number.
# 907 is a happy number.
# 910 is a happy number.
# 912 is a happy number.
# 913 is a happy number.
# 921 is a happy number.
# 923 is a happy number.
# 931 is a happy number.
# 932 is a happy number.
# 937 is a happy number.
# 940 is a happy number.
# 946 is a happy number.
# 964 is a happy number.
# 970 is a happy number.
# 973 is a happy number.
# 989 is a happy number.
# 998 is a happy number.
# 1000 is a happy number.
# 1003 is a happy number.
# 1009 is a happy number.
# 1029 is a happy number.
# 1030 is a happy number.
# 1033 is a happy number.
# 1039 is a happy number.
# 1067 is a happy number.
# 1076 is a happy number.
# 1088 is a happy number.
# 1090 is a happy number.
# 1092 is a happy number.
# 1093 is a happy number.
# 1112 is a happy number.
# 1114 is a happy number.
# 1115 is a happy number.
# 1121 is a happy number.
# 1122 is a happy number.
# 1125 is a happy number.
# 1128 is a happy number.
# 1141 is a happy number.
# 1148 is a happy number.
# 1151 is a happy number.
# 1152 is a happy number.
# 1158 is a happy number.
# 1177 is a happy number.
# 1182 is a happy number.
# 1184 is a happy number.
# 1185 is a happy number.
# 1188 is a happy number.
# 1209 is a happy number.
# 1211 is a happy number.
# 1212 is a happy number.
# 1215 is a happy number.
# 1218 is a happy number.
# 1221 is a happy number.
# 1222 is a happy number.
# 1233 is a happy number.
# 1247 is a happy number.
# 1251 is a happy number.
# 1257 is a happy number.
# 1258 is a happy number.
# 1274 is a happy number.
# 1275 is a happy number.
# 1277 is a happy number.
# 1281 is a happy number.
# 1285 is a happy number.
# 1288 is a happy number.
# 1290 is a happy number.
# 1299 is a happy number.
# 1300 is a happy number.
# 1303 is a happy number.
# 1309 is a happy number.
# 1323 is a happy number.
# 1330 is a happy number.
# 1332 is a happy number.
# 1333 is a happy number.
# 1335 is a happy number.
# 1337 is a happy number.
# 1339 is a happy number.
# 1353 is a happy number.
# 1366 is a happy number.
# 1373 is a happy number.
# 1390 is a happy number.
# 1393 is a happy number.
# 1411 is a happy number.
# 1418 is a happy number.
# 1427 is a happy number.
# 1444 is a happy number.
# 1447 is a happy number.
# 1448 is a happy number.
# 1457 is a happy number.
# 1472 is a happy number.
# 1474 is a happy number.
# 1475 is a happy number.
# 1478 is a happy number.
# 1481 is a happy number.
# 1484 is a happy number.
# 1487 is a happy number.
# 1511 is a happy number.
# 1512 is a happy number.
# 1518 is a happy number.
# 1521 is a happy number.
# 1527 is a happy number.
# 1528 is a happy number.
# 1533 is a happy number.
# 1547 is a happy number.
# 1557 is a happy number.
# 1572 is a happy number.
# 1574 is a happy number.
# 1575 is a happy number.
# 1578 is a happy number.
# 1581 is a happy number.
# 1582 is a happy number.
# 1587 is a happy number.
# 1599 is a happy number.
# 1607 is a happy number.
# 1636 is a happy number.
# 1663 is a happy number.
# 1666 is a happy number.
# 1670 is a happy number.
# 1679 is a happy number.
# 1697 is a happy number.
# 1706 is a happy number.
# 1717 is a happy number.
# 1724 is a happy number.
# 1725 is a happy number.
# 1727 is a happy number.
# 1733 is a happy number.
# 1742 is a happy number.
# 1744 is a happy number.
# 1745 is a happy number.
# 1748 is a happy number.
# 1752 is a happy number.
# 1754 is a happy number.
# 1755 is a happy number.
# 1758 is a happy number.
# 1760 is a happy number.
# 1769 is a happy number.
# 1771 is a happy number.
# 1772 is a happy number.
# 1784 is a happy number.
# 1785 is a happy number.
# 1796 is a happy number.
# 1808 is a happy number.
# 1812 is a happy number.
# 1814 is a happy number.
# 1815 is a happy number.
# 1818 is a happy number.
# 1821 is a happy number.
# 1825 is a happy number.
# 1828 is a happy number.
# 1841 is a happy number.
# 1844 is a happy number.
# 1847 is a happy number.
# 1851 is a happy number.
# 1852 is a happy number.
# 1857 is a happy number.
# 1874 is a happy number.
# 1875 is a happy number.
# 1880 is a happy number.
# 1881 is a happy number.
# 1882 is a happy number.
# 1888 is a happy number.
# 1900 is a happy number.
# 1902 is a happy number.
# 1903 is a happy number.
# 1920 is a happy number.
# 1929 is a happy number.
# 1930 is a happy number.
# 1933 is a happy number.
# 1959 is a happy number.
# 1967 is a happy number.
# 1976 is a happy number.
# 1992 is a happy number.
# 1995 is a happy number.
# 2003 is a happy number.
# 2008 is a happy number.
# 2019 is a happy number.
# 2026 is a happy number.
# 2030 is a happy number.
# 2036 is a happy number.
# 2039 is a happy number.
# 2062 is a happy number.
# 2063 is a happy number.
# 2080 is a happy number.
# 2091 is a happy number.
# 2093 is a happy number.
# 2109 is a happy number.
# 2111 is a happy number.
# 2112 is a happy number.
# 2115 is a happy number.
# 2118 is a happy number.
# 2121 is a happy number.
# 2122 is a happy number.
# 2133 is a happy number.
# 2147 is a happy number.
# 2151 is a happy number.
# 2157 is a happy number.
# 2158 is a happy number.
# 2174 is a happy number.
# 2175 is a happy number.
# 2177 is a happy number.
# 2181 is a happy number.
# 2185 is a happy number.
# 2188 is a happy number.
# 2190 is a happy number.
# 2199 is a happy number.
# 2206 is a happy number.
# 2211 is a happy number.
# 2212 is a happy number.
# 2221 is a happy number.
# 2224 is a happy number.
# 2242 is a happy number.
# 2245 is a happy number.
# 2254 is a happy number.
# 2257 is a happy number.
# 2258 is a happy number.
# 2260 is a happy number.
# 2275 is a happy number.
# 2285 is a happy number.
# 2300 is a happy number.
# 2306 is a happy number.
# 2309 is a happy number.
# 2313 is a happy number.
# 2331 is a happy number.
# 2333 is a happy number.
# 2338 is a happy number.
# 2339 is a happy number.
# 2360 is a happy number.
# 2369 is a happy number.
# 2383 is a happy number.
# 2390 is a happy number.
# 2393 is a happy number.
# 2396 is a happy number.
# 2417 is a happy number.
# 2422 is a happy number.
# 2425 is a happy number.
# 2448 is a happy number.
# 2452 is a happy number.
# 2455 is a happy number.
# 2457 is a happy number.
# 2458 is a happy number.
# 2471 is a happy number.
# 2475 is a happy number.
# 2478 is a happy number.
# 2484 is a happy number.
# 2485 is a happy number.
# 2487 is a happy number.
# 2511 is a happy number.
# 2517 is a happy number.
# 2518 is a happy number.
# 2524 is a happy number.
# 2527 is a happy number.
# 2528 is a happy number.
# 2542 is a happy number.
# 2545 is a happy number.
# 2547 is a happy number.
# 2548 is a happy number.
# 2554 is a happy number.
# 2555 is a happy number.
# 2557 is a happy number.
# 2568 is a happy number.
# 2571 is a happy number.
# 2572 is a happy number.
# 2574 is a happy number.
# 2575 is a happy number.
# 2581 is a happy number.
# 2582 is a happy number.
# 2584 is a happy number.
# 2586 is a happy number.
# 2602 is a happy number.
# 2603 is a happy number.
# 2620 is a happy number.
# 2630 is a happy number.
# 2639 is a happy number.
# 2658 is a happy number.
# 2685 is a happy number.
# 2693 is a happy number.
# 2714 is a happy number.
# 2715 is a happy number.
# 2717 is a happy number.
# 2725 is a happy number.
# 2741 is a happy number.
# 2745 is a happy number.
# 2748 is a happy number.
# 2751 is a happy number.
# 2752 is a happy number.
# 2754 is a happy number.
# 2755 is a happy number.
# 2771 is a happy number.
# 2784 is a happy number.
# 2800 is a happy number.
# 2811 is a happy number.
# 2815 is a happy number.
# 2818 is a happy number.
# 2825 is a happy number.
# 2833 is a happy number.
# 2844 is a happy number.
# 2845 is a happy number.
# 2847 is a happy number.
# 2851 is a happy number.
# 2852 is a happy number.
# 2854 is a happy number.
# 2856 is a happy number.
# 2865 is a happy number.
# 2874 is a happy number.
# 2881 is a happy number.
# 2899 is a happy number.
# 2901 is a happy number.
# 2903 is a happy number.
# 2910 is a happy number.
# 2919 is a happy number.
# 2930 is a happy number.
# 2933 is a happy number.
# 2936 is a happy number.
# 2963 is a happy number.
# 2989 is a happy number.
# 2991 is a happy number.
# 2998 is a happy number.
# 3001 is a happy number.
# 3002 is a happy number.
# 3010 is a happy number.
# 3013 is a happy number.
# 3019 is a happy number.
# 3020 is a happy number.
# 3026 is a happy number.
# 3029 is a happy number.
# 3031 is a happy number.
# 3038 is a happy number.
# 3056 is a happy number.
# 3062 is a happy number.
# 3065 is a happy number.
# 3067 is a happy number.
# 3068 is a happy number.
# 3076 is a happy number.
# 3079 is a happy number.
# 3083 is a happy number.
# 3086 is a happy number.
# 3091 is a happy number.
# 3092 is a happy number.
# 3097 is a happy number.
# 3100 is a happy number.
# 3103 is a happy number.
# 3109 is a happy number.
# 3123 is a happy number.
# 3130 is a happy number.
# 3132 is a happy number.
# 3133 is a happy number.
# 3135 is a happy number.
# 3137 is a happy number.
# 3139 is a happy number.
# 3153 is a happy number.
# 3166 is a happy number.
# 3173 is a happy number.
# 3190 is a happy number.
# 3193 is a happy number.
# 3200 is a happy number.
# 3206 is a happy number.
# 3209 is a happy number.
# 3213 is a happy number.
# 3231 is a happy number.
# 3233 is a happy number.
# 3238 is a happy number.
# 3239 is a happy number.
# 3260 is a happy number.
# 3269 is a happy number.
# 3283 is a happy number.
# 3290 is a happy number.
# 3293 is a happy number.
# 3296 is a happy number.
# 3301 is a happy number.
# 3308 is a happy number.
# 3310 is a happy number.
# 3312 is a happy number.
# 3313 is a happy number.
# 3315 is a happy number.
# 3317 is a happy number.
# 3319 is a happy number.
# 3321 is a happy number.
# 3323 is a happy number.
# 3328 is a happy number.
# 3329 is a happy number.
# 3331 is a happy number.
# 3332 is a happy number.
# 3338 is a happy number.
# 3346 is a happy number.
# 3351 is a happy number.
# 3355 is a happy number.
# 3356 is a happy number.
# 3364 is a happy number.
# 3365 is a happy number.
# 3367 is a happy number.
# 3371 is a happy number.
# 3376 is a happy number.
# 3380 is a happy number.
# 3382 is a happy number.
# 3383 is a happy number.
# 3391 is a happy number.
# 3392 is a happy number.
# 3436 is a happy number.
# 3456 is a happy number.
# 3463 is a happy number.
# 3465 is a happy number.
# 3466 is a happy number.
# 3506 is a happy number.
# 3513 is a happy number.
# 3531 is a happy number.
# 3535 is a happy number.
# 3536 is a happy number.
# 3546 is a happy number.
# 3553 is a happy number.
# 3560 is a happy number.
# 3563 is a happy number.
# 3564 is a happy number.
# 3602 is a happy number.
# 3605 is a happy number.
# 3607 is a happy number.
# 3608 is a happy number.
# 3616 is a happy number.
# 3620 is a happy number.
# 3629 is a happy number.
# 3634 is a happy number.
# 3635 is a happy number.
# 3637 is a happy number.
# 3643 is a happy number.
# 3645 is a happy number.
# 3646 is a happy number.
# 3650 is a happy number.
# 3653 is a happy number.
# 3654 is a happy number.
# 3661 is a happy number.
# 3664 is a happy number.
# 3667 is a happy number.
# 3670 is a happy number.
# 3673 is a happy number.
# 3676 is a happy number.
# 3680 is a happy number.
# 3689 is a happy number.
# 3692 is a happy number.
# 3698 is a happy number.
# 3706 is a happy number.
# 3709 is a happy number.
# 3713 is a happy number.
# 3731 is a happy number.
# 3736 is a happy number.
# 3760 is a happy number.
# 3763 is a happy number.
# 3766 is a happy number.
# 3779 is a happy number.
# 3789 is a happy number.
# 3790 is a happy number.
# 3797 is a happy number.
# 3798 is a happy number.
# 3803 is a happy number.
# 3806 is a happy number.
# 3823 is a happy number.
# 3830 is a happy number.
# 3832 is a happy number.
# 3833 is a happy number.
# 3860 is a happy number.
# 3869 is a happy number.
# 3879 is a happy number.
# 3896 is a happy number.
# 3897 is a happy number.
# 3901 is a happy number.
# 3902 is a happy number.
# 3907 is a happy number.
# 3910 is a happy number.
# 3913 is a happy number.
# 3920 is a happy number.
# 3923 is a happy number.
# 3926 is a happy number.
# 3931 is a happy number.
# 3932 is a happy number.
# 3962 is a happy number.
# 3968 is a happy number.
# 3970 is a happy number.
# 3977 is a happy number.
# 3978 is a happy number.
# 3986 is a happy number.
# 3987 is a happy number.
# 4004 is a happy number.
# 4009 is a happy number.
# 4040 is a happy number.
# 4046 is a happy number.
# 4064 is a happy number.
# 4069 is a happy number.
# 4078 is a happy number.
# 4087 is a happy number.
# 4090 is a happy number.
# 4096 is a happy number.
# 4111 is a happy number.
# 4118 is a happy number.
# 4127 is a happy number.
# 4144 is a happy number.
# 4147 is a happy number.
# 4148 is a happy number.
# 4157 is a happy number.
# 4172 is a happy number.
# 4174 is a happy number.
# 4175 is a happy number.
# 4178 is a happy number.
# 4181 is a happy number.
# 4184 is a happy number.
# 4187 is a happy number.
# 4217 is a happy number.
# 4222 is a happy number.
# 4225 is a happy number.
# 4248 is a happy number.
# 4252 is a happy number.
# 4255 is a happy number.
# 4257 is a happy number.
# 4258 is a happy number.
# 4271 is a happy number.
# 4275 is a happy number.
# 4278 is a happy number.
# 4284 is a happy number.
# 4285 is a happy number.
# 4287 is a happy number.
# 4336 is a happy number.
# 4356 is a happy number.
# 4363 is a happy number.
# 4365 is a happy number.
# 4366 is a happy number.
# 4400 is a happy number.
# 4406 is a happy number.
# 4414 is a happy number.
# 4417 is a happy number.
# 4418 is a happy number.
# 4428 is a happy number.
# 4441 is a happy number.
# 4447 is a happy number.
# 4449 is a happy number.
# 4455 is a happy number.
# 4460 is a happy number.
# 4471 is a happy number.
# 4474 is a happy number.
# 4477 is a happy number.
# 4481 is a happy number.
# 4482 is a happy number.
# 4494 is a happy number.
# 4517 is a happy number.
# 4522 is a happy number.
# 4525 is a happy number.
# 4527 is a happy number.
# 4528 is a happy number.
# 4536 is a happy number.
# 4545 is a happy number.
# 4552 is a happy number.
# 4554 is a happy number.
# 4555 is a happy number.
# 4558 is a happy number.
# 4563 is a happy number.
# 4571 is a happy number.
# 4572 is a happy number.
# 4577 is a happy number.
# 4582 is a happy number.
# 4585 is a happy number.
# 4599 is a happy number.
# 4604 is a happy number.
# 4609 is a happy number.
# 4633 is a happy number.
# 4635 is a happy number.
# 4636 is a happy number.
# 4640 is a happy number.
# 4653 is a happy number.
# 4663 is a happy number.
# 4690 is a happy number.
# 4708 is a happy number.
# 4712 is a happy number.
# 4714 is a happy number.
# 4715 is a happy number.
# 4718 is a happy number.
# 4721 is a happy number.
# 4725 is a happy number.
# 4728 is a happy number.
# 4741 is a happy number.
# 4744 is a happy number.
# 4747 is a happy number.
# 4751 is a happy number.
# 4752 is a happy number.
# 4757 is a happy number.
# 4774 is a happy number.
# 4775 is a happy number.
# 4780 is a happy number.
# 4781 is a happy number.
# 4782 is a happy number.
# 4788 is a happy number.
# 4807 is a happy number.
# 4811 is a happy number.
# 4814 is a happy number.
# 4817 is a happy number.
# 4824 is a happy number.
# 4825 is a happy number.
# 4827 is a happy number.
# 4841 is a happy number.
# 4842 is a happy number.
# 4852 is a happy number.
# 4855 is a happy number.
# 4870 is a happy number.
# 4871 is a happy number.
# 4872 is a happy number.
# 4878 is a happy number.
# 4887 is a happy number.
# 4888 is a happy number.
# 4900 is a happy number.
# 4906 is a happy number.
# 4944 is a happy number.
# 4959 is a happy number.
# 4960 is a happy number.
# 4995 is a happy number.
# 5036 is a happy number.
# 5056 is a happy number.
# 5063 is a happy number.
# 5065 is a happy number.
# 5066 is a happy number.
# 5111 is a happy number.
# 5112 is a happy number.
# 5118 is a happy number.
# 5121 is a happy number.
# 5127 is a happy number.
# 5128 is a happy number.
# 5133 is a happy number.
# 5147 is a happy number.
# 5157 is a happy number.
# 5172 is a happy number.
# 5174 is a happy number.
# 5175 is a happy number.
# 5178 is a happy number.
# 5181 is a happy number.
# 5182 is a happy number.
# 5187 is a happy number.
# 5199 is a happy number.
# 5211 is a happy number.
# 5217 is a happy number.
# 5218 is a happy number.
# 5224 is a happy number.
# 5227 is a happy number.
# 5228 is a happy number.
# 5242 is a happy number.
# 5245 is a happy number.
# 5247 is a happy number.
# 5248 is a happy number.
# 5254 is a happy number.
# 5255 is a happy number.
# 5257 is a happy number.
# 5268 is a happy number.
# 5271 is a happy number.
# 5272 is a happy number.
# 5274 is a happy number.
# 5275 is a happy number.
# 5281 is a happy number.
# 5282 is a happy number.
# 5284 is a happy number.
# 5286 is a happy number.
# 5306 is a happy number.
# 5313 is a happy number.
# 5331 is a happy number.
# 5335 is a happy number.
# 5336 is a happy number.
# 5346 is a happy number.
# 5353 is a happy number.
# 5360 is a happy number.
# 5363 is a happy number.
# 5364 is a happy number.
# 5417 is a happy number.
# 5422 is a happy number.
# 5425 is a happy number.
# 5427 is a happy number.
# 5428 is a happy number.
# 5436 is a happy number.
# 5445 is a happy number.
# 5452 is a happy number.
# 5454 is a happy number.
# 5455 is a happy number.
# 5458 is a happy number.
# 5463 is a happy number.
# 5471 is a happy number.
# 5472 is a happy number.
# 5477 is a happy number.
# 5482 is a happy number.
# 5485 is a happy number.
# 5499 is a happy number.
# 5506 is a happy number.
# 5517 is a happy number.
# 5524 is a happy number.
# 5525 is a happy number.
# 5527 is a happy number.
# 5533 is a happy number.
# 5542 is a happy number.
# 5544 is a happy number.
# 5545 is a happy number.
# 5548 is a happy number.
# 5552 is a happy number.
# 5554 is a happy number.
# 5555 is a happy number.
# 5558 is a happy number.
# 5560 is a happy number.
# 5569 is a happy number.
# 5571 is a happy number.
# 5572 is a happy number.
# 5584 is a happy number.
# 5585 is a happy number.
# 5596 is a happy number.
# 5603 is a happy number.
# 5605 is a happy number.
# 5606 is a happy number.
# 5628 is a happy number.
# 5630 is a happy number.
# 5633 is a happy number.
# 5634 is a happy number.
# 5643 is a happy number.
# 5650 is a happy number.
# 5659 is a happy number.
# 5660 is a happy number.
# 5666 is a happy number.
# 5682 is a happy number.
# 5695 is a happy number.
# 5712 is a happy number.
# 5714 is a happy number.
# 5715 is a happy number.
# 5718 is a happy number.
# 5721 is a happy number.
# 5722 is a happy number.
# 5724 is a happy number.
# 5725 is a happy number.
# 5741 is a happy number.
# 5742 is a happy number.
# 5747 is a happy number.
# 5751 is a happy number.
# 5752 is a happy number.
# 5774 is a happy number.
# 5781 is a happy number.
# 5789 is a happy number.
# 5798 is a happy number.
# 5799 is a happy number.
# 5811 is a happy number.
# 5812 is a happy number.
# 5817 is a happy number.
# 5821 is a happy number.
# 5822 is a happy number.
# 5824 is a happy number.
# 5826 is a happy number.
# 5842 is a happy number.
# 5845 is a happy number.
# 5854 is a happy number.
# 5855 is a happy number.
# 5862 is a happy number.
# 5871 is a happy number.
# 5879 is a happy number.
# 5897 is a happy number.
# 5919 is a happy number.
# 5949 is a happy number.
# 5956 is a happy number.
# 5965 is a happy number.
# 5978 is a happy number.
# 5979 is a happy number.
# 5987 is a happy number.
# 5991 is a happy number.
# 5994 is a happy number.
# 5997 is a happy number.
# 6008 is a happy number.
# 6017 is a happy number.
# 6022 is a happy number.
# 6023 is a happy number.
# 6032 is a happy number.
# 6035 is a happy number.
# 6037 is a happy number.
# 6038 is a happy number.
# 6044 is a happy number.
# 6049 is a happy number.
# 6053 is a happy number.
# 6055 is a happy number.
# 6056 is a happy number.
# 6065 is a happy number.
# 6071 is a happy number.
# 6073 is a happy number.
# 6080 is a happy number.
# 6083 is a happy number.
# 6094 is a happy number.
# 6107 is a happy number.
# 6136 is a happy number.
# 6163 is a happy number.
# 6166 is a happy number.
# 6170 is a happy number.
# 6179 is a happy number.
# 6197 is a happy number.
# 6202 is a happy number.
# 6203 is a happy number.
# 6220 is a happy number.
# 6230 is a happy number.
# 6239 is a happy number.
# 6258 is a happy number.
# 6285 is a happy number.
# 6293 is a happy number.
# 6302 is a happy number.
# 6305 is a happy number.
# 6307 is a happy number.
# 6308 is a happy number.
# 6316 is a happy number.
# 6320 is a happy number.
# 6329 is a happy number.
# 6334 is a happy number.
# 6335 is a happy number.
# 6337 is a happy number.
# 6343 is a happy number.
# 6345 is a happy number.
# 6346 is a happy number.
# 6350 is a happy number.
# 6353 is a happy number.
# 6354 is a happy number.
# 6361 is a happy number.
# 6364 is a happy number.
# 6367 is a happy number.
# 6370 is a happy number.
# 6373 is a happy number.
# 6376 is a happy number.
# 6380 is a happy number.
# 6389 is a happy number.
# 6392 is a happy number.
# 6398 is a happy number.
# 6404 is a happy number.
# 6409 is a happy number.
# 6433 is a happy number.
# 6435 is a happy number.
# 6436 is a happy number.
# 6440 is a happy number.
# 6453 is a happy number.
# 6463 is a happy number.
# 6490 is a happy number.
# 6503 is a happy number.
# 6505 is a happy number.
# 6506 is a happy number.
# 6528 is a happy number.
# 6530 is a happy number.
# 6533 is a happy number.
# 6534 is a happy number.
# 6543 is a happy number.
# 6550 is a happy number.
# 6559 is a happy number.
# 6560 is a happy number.
# 6566 is a happy number.
# 6582 is a happy number.
# 6595 is a happy number.
# 6605 is a happy number.
# 6613 is a happy number.
# 6616 is a happy number.
# 6631 is a happy number.
# 6634 is a happy number.
# 6637 is a happy number.
# 6643 is a happy number.
# 6650 is a happy number.
# 6656 is a happy number.
# 6661 is a happy number.
# 6665 is a happy number.
# 6673 is a happy number.
# 6701 is a happy number.
# 6703 is a happy number.
# 6710 is a happy number.
# 6719 is a happy number.
# 6730 is a happy number.
# 6733 is a happy number.
# 6736 is a happy number.
# 6763 is a happy number.
# 6789 is a happy number.
# 6791 is a happy number.
# 6798 is a happy number.
# 6800 is a happy number.
# 6803 is a happy number.
# 6825 is a happy number.
# 6830 is a happy number.
# 6839 is a happy number.
# 6852 is a happy number.
# 6879 is a happy number.
# 6893 is a happy number.
# 6897 is a happy number.
# 6899 is a happy number.
# 6904 is a happy number.
# 6917 is a happy number.
# 6923 is a happy number.
# 6932 is a happy number.
# 6938 is a happy number.
# 6940 is a happy number.
# 6955 is a happy number.
# 6971 is a happy number.
# 6978 is a happy number.
# 6983 is a happy number.
# 6987 is a happy number.
# 6989 is a happy number.
# 6998 is a happy number.
# 7000 is a happy number.
# 7009 is a happy number.
# 7016 is a happy number.
# 7036 is a happy number.
# 7039 is a happy number.
# 7048 is a happy number.
# 7061 is a happy number.
# 7063 is a happy number.
# 7084 is a happy number.
# 7090 is a happy number.
# 7093 is a happy number.
# 7106 is a happy number.
# 7117 is a happy number.
# 7124 is a happy number.
# 7125 is a happy number.
# 7127 is a happy number.
# 7133 is a happy number.
# 7142 is a happy number.
# 7144 is a happy number.
# 7145 is a happy number.
# 7148 is a happy number.
# 7152 is a happy number.
# 7154 is a happy number.
# 7155 is a happy number.
# 7158 is a happy number.
# 7160 is a happy number.
# 7169 is a happy number.
# 7171 is a happy number.
# 7172 is a happy number.
# 7184 is a happy number.
# 7185 is a happy number.
# 7196 is a happy number.
# 7214 is a happy number.
# 7215 is a happy number.
# 7217 is a happy number.
# 7225 is a happy number.
# 7241 is a happy number.
# 7245 is a happy number.
# 7248 is a happy number.
# 7251 is a happy number.
# 7252 is a happy number.
# 7254 is a happy number.
# 7255 is a happy number.
# 7271 is a happy number.
# 7284 is a happy number.
# 7306 is a happy number.
# 7309 is a happy number.
# 7313 is a happy number.
# 7331 is a happy number.
# 7336 is a happy number.
# 7360 is a happy number.
# 7363 is a happy number.
# 7366 is a happy number.
# 7379 is a happy number.
# 7389 is a happy number.
# 7390 is a happy number.
# 7397 is a happy number.
# 7398 is a happy number.
# 7408 is a happy number.
# 7412 is a happy number.
# 7414 is a happy number.
# 7415 is a happy number.
# 7418 is a happy number.
# 7421 is a happy number.
# 7425 is a happy number.
# 7428 is a happy number.
# 7441 is a happy number.
# 7444 is a happy number.
# 7447 is a happy number.
# 7451 is a happy number.
# 7452 is a happy number.
# 7457 is a happy number.
# 7474 is a happy number.
# 7475 is a happy number.
# 7480 is a happy number.
# 7481 is a happy number.
# 7482 is a happy number.
# 7488 is a happy number.
# 7512 is a happy number.
# 7514 is a happy number.
# 7515 is a happy number.
# 7518 is a happy number.
# 7521 is a happy number.
# 7522 is a happy number.
# 7524 is a happy number.
# 7525 is a happy number.
# 7541 is a happy number.
# 7542 is a happy number.
# 7547 is a happy number.
# 7551 is a happy number.
# 7552 is a happy number.
# 7574 is a happy number.
# 7581 is a happy number.
# 7589 is a happy number.
# 7598 is a happy number.
# 7599 is a happy number.
# 7601 is a happy number.
# 7603 is a happy number.
# 7610 is a happy number.
# 7619 is a happy number.
# 7630 is a happy number.
# 7633 is a happy number.
# 7636 is a happy number.
# 7663 is a happy number.
# 7689 is a happy number.
# 7691 is a happy number.
# 7698 is a happy number.
# 7711 is a happy number.
# 7712 is a happy number.
# 7721 is a happy number.
# 7739 is a happy number.
# 7744 is a happy number.
# 7745 is a happy number.
# 7754 is a happy number.
# 7788 is a happy number.
# 7793 is a happy number.
# 7804 is a happy number.
# 7814 is a happy number.
# 7815 is a happy number.
# 7824 is a happy number.
# 7839 is a happy number.
# 7840 is a happy number.
# 7841 is a happy number.
# 7842 is a happy number.
# 7848 is a happy number.
# 7851 is a happy number.
# 7859 is a happy number.
# 7869 is a happy number.
# 7878 is a happy number.
# 7884 is a happy number.
# 7887 is a happy number.
# 7893 is a happy number.
# 7895 is a happy number.
# 7896 is a happy number.
# 7900 is a happy number.
# 7903 is a happy number.
# 7916 is a happy number.
# 7930 is a happy number.
# 7937 is a happy number.
# 7938 is a happy number.
# 7958 is a happy number.
# 7959 is a happy number.
# 7961 is a happy number.
# 7968 is a happy number.
# 7973 is a happy number.
# 7983 is a happy number.
# 7985 is a happy number.
# 7986 is a happy number.
# 7995 is a happy number.
# 8002 is a happy number.
# 8006 is a happy number.
# 8018 is a happy number.
# 8020 is a happy number.
# 8033 is a happy number.
# 8036 is a happy number.
# 8047 is a happy number.
# 8060 is a happy number.
# 8063 is a happy number.
# 8074 is a happy number.
# 8081 is a happy number.
# 8088 is a happy number.
# 8099 is a happy number.
# 8108 is a happy number.
# 8112 is a happy number.
# 8114 is a happy number.
# 8115 is a happy number.
# 8118 is a happy number.
# 8121 is a happy number.
# 8125 is a happy number.
# 8128 is a happy number.
# 8141 is a happy number.
# 8144 is a happy number.
# 8147 is a happy number.
# 8151 is a happy number.
# 8152 is a happy number.
# 8157 is a happy number.
# 8174 is a happy number.
# 8175 is a happy number.
# 8180 is a happy number.
# 8181 is a happy number.
# 8182 is a happy number.
# 8188 is a happy number.
# 8200 is a happy number.
# 8211 is a happy number.
# 8215 is a happy number.
# 8218 is a happy number.
# 8225 is a happy number.
# 8233 is a happy number.
# 8244 is a happy number.
# 8245 is a happy number.
# 8247 is a happy number.
# 8251 is a happy number.
# 8252 is a happy number.
# 8254 is a happy number.
# 8256 is a happy number.
# 8265 is a happy number.
# 8274 is a happy number.
# 8281 is a happy number.
# 8299 is a happy number.
# 8303 is a happy number.
# 8306 is a happy number.
# 8323 is a happy number.
# 8330 is a happy number.
# 8332 is a happy number.
# 8333 is a happy number.
# 8360 is a happy number.
# 8369 is a happy number.
# 8379 is a happy number.
# 8396 is a happy number.
# 8397 is a happy number.
# 8407 is a happy number.
# 8411 is a happy number.
# 8414 is a happy number.
# 8417 is a happy number.
# 8424 is a happy number.
# 8425 is a happy number.
# 8427 is a happy number.
# 8441 is a happy number.
# 8442 is a happy number.
# 8452 is a happy number.
# 8455 is a happy number.
# 8470 is a happy number.
# 8471 is a happy number.
# 8472 is a happy number.
# 8478 is a happy number.
# 8487 is a happy number.
# 8488 is a happy number.
# 8511 is a happy number.
# 8512 is a happy number.
# 8517 is a happy number.
# 8521 is a happy number.
# 8522 is a happy number.
# 8524 is a happy number.
# 8526 is a happy number.
# 8542 is a happy number.
# 8545 is a happy number.
# 8554 is a happy number.
# 8555 is a happy number.
# 8562 is a happy number.
# 8571 is a happy number.
# 8579 is a happy number.
# 8597 is a happy number.
# 8600 is a happy number.
# 8603 is a happy number.
# 8625 is a happy number.
# 8630 is a happy number.
# 8639 is a happy number.
# 8652 is a happy number.
# 8679 is a happy number.
# 8693 is a happy number.
# 8697 is a happy number.
# 8699 is a happy number.
# 8704 is a happy number.
# 8714 is a happy number.
# 8715 is a happy number.
# 8724 is a happy number.
# 8739 is a happy number.
# 8740 is a happy number.
# 8741 is a happy number.
# 8742 is a happy number.
# 8748 is a happy number.
# 8751 is a happy number.
# 8759 is a happy number.
# 8769 is a happy number.
# 8778 is a happy number.
# 8784 is a happy number.
# 8787 is a happy number.
# 8793 is a happy number.
# 8795 is a happy number.
# 8796 is a happy number.
# 8801 is a happy number.
# 8808 is a happy number.
# 8810 is a happy number.
# 8811 is a happy number.
# 8812 is a happy number.
# 8818 is a happy number.
# 8821 is a happy number.
# 8847 is a happy number.
# 8848 is a happy number.
# 8874 is a happy number.
# 8877 is a happy number.
# 8880 is a happy number.
# 8881 is a happy number.
# 8884 is a happy number.
# 8909 is a happy number.
# 8929 is a happy number.
# 8936 is a happy number.
# 8937 is a happy number.
# 8957 is a happy number.
# 8963 is a happy number.
# 8967 is a happy number.
# 8969 is a happy number.
# 8973 is a happy number.
# 8975 is a happy number.
# 8976 is a happy number.
# 8990 is a happy number.
# 8992 is a happy number.
# 8996 is a happy number.
# 9001 is a happy number.
# 9004 is a happy number.
# 9007 is a happy number.
# 9010 is a happy number.
# 9012 is a happy number.
# 9013 is a happy number.
# 9021 is a happy number.
# 9023 is a happy number.
# 9031 is a happy number.
# 9032 is a happy number.
# 9037 is a happy number.
# 9040 is a happy number.
# 9046 is a happy number.
# 9064 is a happy number.
# 9070 is a happy number.
# 9073 is a happy number.
# 9089 is a happy number.
# 9098 is a happy number.
# 9100 is a happy number.
# 9102 is a happy number.
# 9103 is a happy number.
# 9120 is a happy number.
# 9129 is a happy number.
# 9130 is a happy number.
# 9133 is a happy number.
# 9159 is a happy number.
# 9167 is a happy number.
# 9176 is a happy number.
# 9192 is a happy number.
# 9195 is a happy number.
# 9201 is a happy number.
# 9203 is a happy number.
# 9210 is a happy number.
# 9219 is a happy number.
# 9230 is a happy number.
# 9233 is a happy number.
# 9236 is a happy number.
# 9263 is a happy number.
# 9289 is a happy number.
# 9291 is a happy number.
# 9298 is a happy number.
# 9301 is a happy number.
# 9302 is a happy number.
# 9307 is a happy number.
# 9310 is a happy number.
# 9313 is a happy number.
# 9320 is a happy number.
# 9323 is a happy number.
# 9326 is a happy number.
# 9331 is a happy number.
# 9332 is a happy number.
# 9362 is a happy number.
# 9368 is a happy number.
# 9370 is a happy number.
# 9377 is a happy number.
# 9378 is a happy number.
# 9386 is a happy number.
# 9387 is a happy number.
# 9400 is a happy number.
# 9406 is a happy number.
# 9444 is a happy number.
# 9459 is a happy number.
# 9460 is a happy number.
# 9495 is a happy number.
# 9519 is a happy number.
# 9549 is a happy number.
# 9556 is a happy number.
# 9565 is a happy number.
# 9578 is a happy number.
# 9579 is a happy number.
# 9587 is a happy number.
# 9591 is a happy number.
# 9594 is a happy number.
# 9597 is a happy number.
# 9604 is a happy number.
# 9617 is a happy number.
# 9623 is a happy number.
# 9632 is a happy number.
# 9638 is a happy number.
# 9640 is a happy number.
# 9655 is a happy number.
# 9671 is a happy number.
# 9678 is a happy number.
# 9683 is a happy number.
# 9687 is a happy number.
# 9689 is a happy number.
# 9698 is a happy number.
# 9700 is a happy number.
# 9703 is a happy number.
# 9716 is a happy number.
# 9730 is a happy number.
# 9737 is a happy number.
# 9738 is a happy number.
# 9758 is a happy number.
# 9759 is a happy number.
# 9761 is a happy number.
# 9768 is a happy number.
# 9773 is a happy number.
# 9783 is a happy number.
# 9785 is a happy number.
# 9786 is a happy number.
# 9795 is a happy number.
# 9809 is a happy number.
# 9829 is a happy number.
# 9836 is a happy number.
# 9837 is a happy number.
# 9857 is a happy number.
# 9863 is a happy number.
# 9867 is a happy number.
# 9869 is a happy number.
# 9873 is a happy number.
# 9875 is a happy number.
# 9876 is a happy number.
# 9890 is a happy number.
# 9892 is a happy number.
# 9896 is a happy number.
# 9908 is a happy number.
# 9912 is a happy number.
# 9915 is a happy number.
# 9921 is a happy number.
# 9928 is a happy number.
# 9945 is a happy number.
# 9951 is a happy number.
# 9954 is a happy number.
# 9957 is a happy number.
# 9968 is a happy number.
# 9975 is a happy number.
# 9980 is a happy number.
# 9982 is a happy number.
# 9986 is a happy number.

# %%
number = input("Enter the number: ")

def is_happy_number(n):
    while n != 1 and n != 4 :
        n = sum(int(i)**2 for i in str(n))
    return n == 1

is_happy_number(number)
# Out:
# True

# %%
def is_happy_num(n):
    seen_numbers = set({4, 16, 20, 37, 58, 89})
    while n != 1 and n not in seen_numbers :
        seen_numbers.add(n)
        n = sum(int(i)**2 for i in str(n))
        print(n)
    print(seen_numbers)
    return n == 1

# %%
is_happy_num(28963698745225891)
# Out:
# 644
# 68
# 100
# 1
# {4, 644, 68, 16, 20, 89, 28963698745225891, 100, 37, 58}
# True
